# %%
import torch
ckpt = torch.load("snake_dqn_best.pth", weights_only=False)
print(ckpt["model_state_dict"].keys())
# Out:
# odict_keys(['network.0.weight', 'network.0.bias', 'network.2.weight', 'network.2.bias', 'network.4.weight', 'network.4.bias', 'network.6.weight', 'network.6.bias'])
